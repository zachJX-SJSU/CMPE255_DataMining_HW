# %% [markdown]
# Part I. Association Rule Mining

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=662c8b2dd2d985c75b9dc75bab6cda4fe73d46511100f58aba32c8fc9e4a6244
#   Stored in directory: /root/.cache/pip/wheels/7f/49/e3/42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori
# Pycaret no longer supports arules
# from pycaret.arules import *

store_data = pd.read_csv('transactions.csv') # Removed header=None
print(store_data.head())
print(store_data.shape)
# Out:
#    transaction_id                                             item_1  \
# 0               1  Honeywell 5800CO Carbon Monoxide Detector (SKU...
# 1               2   Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)
# 2               3         Bosch F220-B6 Detector Base (SKU: F220-B6)
# 3               4  GE Interlogix 60-652-95R Carbon Monoxide Detec...
# 4               5   Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)
#
#                                               item_2  \
# 0                Hanwha XRN-2010 NVR (SKU: XRN-2010)
# 1             Bosch B5512 Control Panel (SKU: B5512)
# 2  GE Interlogix 60-652-95R Carbon Monoxide Detec...
# 3         Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)
# 4       Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#
#                                               item_3  \
# 0                                                NaN
# 1     Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
# 2  DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)
# 3   Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)
# 4            DSC WS4916 Smoke Detector (SKU: WS4916)
#
#                                               item_4  \
# 0                                                NaN
# 1  GE Interlogix 60-807-95R Glassbreak Detector (...
# 2                                                NaN
# 3  Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-I...
# 4       Axis P3367-VE Network Camera (SKU: 0407-001)
#
#                                               item_5
# 0                                                NaN
# 1         Bosch F220-B6 Detector Base (SKU: F220-B6)
# 2                                                NaN
# 3             Bosch B5512 Control Panel (SKU: B5512)
# 4  Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-I...
# (1000, 6)

# %%
# Build the transaction list
item_cols = [c for c in store_data.columns if c.startswith("item_")]

transactions = []

for _, row in store_data.iterrows():
    # Extract item names from the row
    items = [str(row[c]).strip() for c in item_cols if pd.notna(row[c]) and str(row[c]).strip() != ""]

    # Deduplicate while preserving order
    seen = set()
    clean_items = []
    for i in items:
        if i not in seen:
            seen.add(i)
            clean_items.append(i)

    # Append the cleaned list if it’s not empty
    if clean_items:
        transactions.append(clean_items)

# --- 4) Inspect the result ---
print(f"✅ Built {len(transactions)} transactions.")
print("First few transactions:")
for t in transactions[:10]:
    print(t)
# Out:
# ✅ Built 1000 transactions.
# First few transactions:
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Hanwha XRN-2010 NVR (SKU: XRN-2010)']
# ['Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Bosch B5512 Control Panel (SKU: B5512)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)', 'GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R)', 'Bosch F220-B6 Detector Base (SKU: F220-B6)']
# ['Bosch F220-B6 Detector Base (SKU: F220-B6)', 'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)']
# ['GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)', 'Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)', 'Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)', 'Bosch B5512 Control Panel (SKU: B5512)']
# ['Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)', 'DSC WS4916 Smoke Detector (SKU: WS4916)', 'Axis P3367-VE Network Camera (SKU: 0407-001)', 'Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)']
# ['Hanwha XRN-2010 NVR (SKU: XRN-2010)', 'Bosch D7050 Detector (SKU: D7050)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)', 'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)']
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)']
# ['DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)', 'Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)', 'GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)']
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Bosch B5512 Control Panel (SKU: B5512)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)', 'GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)']
# ['Honeywell 5808W3 Smoke Detector (SKU: 5808W3)', 'Bosch F220-B6 Detector Base (SKU: F220-B6)']

# %%
all_items = [item for txn in transactions for item in txn]

# Get unique items while preserving the order they first appear
seen = set()
unique_items = []
for item in all_items:
    if item not in seen:
        seen.add(item)
        unique_items.append(item)

# Create a DataFrame with sequential item_id
item_list_df = pd.DataFrame({
    "item_id": range(1, len(unique_items) + 1),
    "item": unique_items
})

# --- 5) Save item list to CSV ---
ITEM_LIST_PATH = "item_list.csv"
item_list_df.to_csv(ITEM_LIST_PATH, index=False)
print(f"\n✅ Saved item list to '{ITEM_LIST_PATH}' with {len(item_list_df)} unique items.")

# --- 6) Optional preview ---
print("\nItem list preview:")
print(item_list_df)
# Out:
# ✅ Saved item list to 'item_list.csv' with 40 unique items.
#
# Item list preview:
#     item_id                                               item
# 0         1  Honeywell 5800CO Carbon Monoxide Detector (SKU...
# 1         2                Hanwha XRN-2010 NVR (SKU: XRN-2010)
# 2         3   Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)
# 3         4             Bosch B5512 Control Panel (SKU: B5512)
# 4         5     Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
# 5         6  GE Interlogix 60-807-95R Glassbreak Detector (...
# 6         7         Bosch F220-B6 Detector Base (SKU: F220-B6)
# 7         8  GE Interlogix 60-652-95R Carbon Monoxide Detec...
# 8         9  DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)
# 9        10         Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)
# 10       11   Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)
# 11       12  Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-I...
# 12       13       Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
# 13       14            DSC WS4916 Smoke Detector (SKU: WS4916)
# 14       15       Axis P3367-VE Network Camera (SKU: 0407-001)
# 15       16                  Bosch D7050 Detector (SKU: D7050)
# 16       17  Honeywell VISTA-20P Control Panel (SKU: VISTA-...
# 17       18  Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2...
# 18       19  Honeywell 5800PIR-RES Motion Detector (SKU: 58...
# 19       20  Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC...
# 20       21      DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)
# 21       22  GE Interlogix 60-848-02-95R Smoke Detector (SK...
# 22       23      Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
# 23       24  Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-...
# 24       25  GE Interlogix 60-746-01-95R Wireless Keypad (S...
# 25       26     Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)
# 26       27              DSC WS4939 Wireless Key (SKU: WS4939)
# 27       28       Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
# 28       29           Bosch B810 Wireless Receiver (SKU: B810)
# 29       30                  Bosch DS160 Detector (SKU: DS160)
# 30       31     Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)
# 31       32  Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-...
# 32       33   Hanwha QND-6010R Network Camera (SKU: QND-6010R)
# 33       34      Axis P3225-LVE Network Camera (SKU: 0935-001)
# 34       35             Honeywell HEN08104 NVR (SKU: HEN08104)
# 35       36                  Honeywell 6160 Keypad (SKU: 6160)
# 36       37           DSC PG9914 Motion Detector (SKU: PG9914)
# 37       38       GE Interlogix NX-8 Control Panel (SKU: NX-8)
# 38       39        Axis M3046-V Network Camera (SKU: 0806-001)
# 39       40  Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03...

# %%
# association_rules = apriori(records, min_support=0.0045, min_confidence=0.001, min_length=2)
association_rules = apriori(transactions, min_support=0.005, min_confidence=0.01)
association_results = list(association_rules)

# %%
# print(association_results)

print(association_results[:3])

print(str(len(association_results)) + " items\n")
# Out:
# [RelationRecord(items=frozenset({'Axis M3046-V Network Camera (SKU: 0806-001)'}), support=0.08, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Axis M3046-V Network Camera (SKU: 0806-001)'}), confidence=0.08, lift=1.0)]), RelationRecord(items=frozenset({'Axis P3225-LVE Network Camera (SKU: 0935-001)'}), support=0.089, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Axis P3225-LVE Network Camera (SKU: 0935-001)'}), confidence=0.089, lift=1.0)]), RelationRecord(items=frozenset({'Axis P3367-VE Network Camera (SKU: 0407-001)'}), support=0.09, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Axis P3367-VE Network Camera (SKU: 0407-001)'}), confidence=0.09, lift=1.0)])]
# 673 items

# %%
for association in association_results:

    # first index of the inner list
    # Contains base item and add item

    items = [x for x in association[0]]
    if (len(association[0]) < 2):
        continue
    print(items)
    print("Support: " + str(association[1]))

    for rule in association[2]:
      # print("Rule: " + ",".join(items[:-1]) + " -> " + items[-1])
      LHS = set(rule[0])
      RHS = set(rule[1])
      print("--Rule: " + ",".join(LHS) + " -> " + ",".join(RHS))
      #second index of the inner list


      #third index of the list located at 0th
      #of the third index of the inner list
      print("  Confidence: " + str(association[2][0][2]))
      print("  Lift: " + str(association[2][0][3]))



print("DONE****")
# Out:
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.009
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.11249999999999999
#   Lift: 1.2640449438202246
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.11249999999999999
#   Lift: 1.2640449438202246
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.008
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.1
#   Lift: 1.1111111111111112
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.1
#   Lift: 1.1111111111111112
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.0875
#   Lift: 0.9510869565217391
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0875
#   Lift: 0.9510869565217391
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Bosch B810 Wireless Receiver (SKU: B810)']
# Support: 0.005
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch B810 Wireless Receiver (SKU: B810)
#   Confidence: 0.0625
#   Lift: 0.7183908045977012
# --Rule: Bosch B810 Wireless Receiver (SKU: B810) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0625
#   Lift: 0.7183908045977012
# ['Bosch DS160 Detector (SKU: DS160)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.01
# --Rule:  -> Bosch DS160 Detector (SKU: DS160),Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch DS160 Detector (SKU: DS160)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Bosch DS160 Detector (SKU: DS160) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.01
#   Lift: 1.0
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Bosch F220-B6 Detector Base (SKU: F220-B6)']
# Support: 0.005
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch F220-B6 Detector Base (SKU: F220-B6)
#   Confidence: 0.0625
#   Lift: 0.702247191011236
# --Rule: Bosch F220-B6 Detector Base (SKU: F220-B6) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0625
#   Lift: 0.702247191011236
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)']
# Support: 0.005
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)
#   Confidence: 0.0625
#   Lift: 0.702247191011236
# --Rule: Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0625
#   Lift: 0.702247191011236
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)']
# Support: 0.006
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)
#   Confidence: 0.075
#   Lift: 0.9259259259259258
# --Rule: Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.075
#   Lift: 0.9259259259259258
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)']
# Support: 0.005
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)
#   Confidence: 0.0625
#   Lift: 0.6944444444444444
# --Rule: Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0625
#   Lift: 0.6944444444444444
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'DSC PG9914 Motion Detector (SKU: PG9914)']
# Support: 0.008
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> DSC PG9914 Motion Detector (SKU: PG9914)
#   Confidence: 0.1
#   Lift: 1.0416666666666667
# --Rule: DSC PG9914 Motion Detector (SKU: PG9914) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.1
#   Lift: 1.0416666666666667
# ['DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.011
# --Rule:  -> DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK),Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.011
#   Lift: 1.0
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)']
# Support: 0.007
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)
#   Confidence: 0.0875
#   Lift: 1.0057471264367817
# --Rule: DSC WS4933 Carbon Monoxide Detector (SKU: WS4933) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0875
#   Lift: 1.0057471264367817
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'DSC WS4939 Wireless Key (SKU: WS4939)']
# Support: 0.007
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> DSC WS4939 Wireless Key (SKU: WS4939)
#   Confidence: 0.0875
#   Lift: 0.8663366336633662
# --Rule: DSC WS4939 Wireless Key (SKU: WS4939) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0875
#   Lift: 0.8663366336633662
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)']
# Support: 0.008
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)
#   Confidence: 0.1
#   Lift: 0.9523809523809524
# --Rule: Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.1
#   Lift: 0.9523809523809524
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)']
# Support: 0.011
# --Rule:  -> Axis M3046-V Network Camera (SKU: 0806-001),Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.011
#   Lift: 1.0
# ['GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.006
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)
#   Confidence: 0.075
#   Lift: 0.7575757575757575
# --Rule: GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.075
#   Lift: 0.7575757575757575
# ['GE Interlogix NX-8 Control Panel (SKU: NX-8)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.01
# --Rule:  -> GE Interlogix NX-8 Control Panel (SKU: NX-8),Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> GE Interlogix NX-8 Control Panel (SKU: NX-8)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: GE Interlogix NX-8 Control Panel (SKU: NX-8) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.01
#   Lift: 1.0
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Hanwha QND-6010R Network Camera (SKU: QND-6010R)']
# Support: 0.008
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Hanwha QND-6010R Network Camera (SKU: QND-6010R)
#   Confidence: 0.1
#   Lift: 1.0752688172043012
# --Rule: Hanwha QND-6010R Network Camera (SKU: QND-6010R) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.1
#   Lift: 1.0752688172043012
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Hanwha XRN-2010 NVR (SKU: XRN-2010)']
# Support: 0.005
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Hanwha XRN-2010 NVR (SKU: XRN-2010)
#   Confidence: 0.0625
#   Lift: 0.78125
# --Rule: Hanwha XRN-2010 NVR (SKU: XRN-2010) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0625
#   Lift: 0.78125
# ['Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.007
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)
#   Confidence: 0.0875
#   Lift: 0.8663366336633662
# --Rule: Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0875
#   Lift: 0.8663366336633662
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)']
# Support: 0.005
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)
#   Confidence: 0.0625
#   Lift: 0.7352941176470588
# --Rule: Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0625
#   Lift: 0.7352941176470588
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)']
# Support: 0.007
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)
#   Confidence: 0.0875
#   Lift: 0.902061855670103
# --Rule: Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.0875
#   Lift: 0.902061855670103
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.006
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.075
#   Lift: 0.9493670886075949
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.075
#   Lift: 0.9493670886075949
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Axis M3046-V Network Camera (SKU: 0806-001)']
# Support: 0.006
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.075
#   Lift: 0.8620689655172414
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.075
#   Lift: 0.8620689655172414
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)']
# Support: 0.008
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.1
#   Lift: 1.149425287356322
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.1
#   Lift: 1.149425287356322
# ['Axis M3046-V Network Camera (SKU: 0806-001)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.012
# --Rule:  -> Axis M3046-V Network Camera (SKU: 0806-001),Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.012
#   Lift: 1.0
# --Rule: Axis M3046-V Network Camera (SKU: 0806-001) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.012
#   Lift: 1.0
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Axis M3046-V Network Camera (SKU: 0806-001)
#   Confidence: 0.012
#   Lift: 1.0
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.08988764044943821
#   Lift: 0.9987515605493135
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 0.9987515605493135
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.009
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.10112359550561797
#   Lift: 1.0991695163654127
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.10112359550561797
#   Lift: 1.0991695163654127
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Bosch B810 Wireless Receiver (SKU: B810)']
# Support: 0.009
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch B810 Wireless Receiver (SKU: B810)
#   Confidence: 0.10112359550561797
#   Lift: 1.162340178225494
# --Rule: Bosch B810 Wireless Receiver (SKU: B810) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.10112359550561797
#   Lift: 1.162340178225494
# ['Bosch D7050 Detector (SKU: D7050)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.006
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch D7050 Detector (SKU: D7050)
#   Confidence: 0.06741573033707865
#   Lift: 0.6809669731018045
# --Rule: Bosch D7050 Detector (SKU: D7050) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.06741573033707865
#   Lift: 0.6809669731018045
# ['Bosch DS160 Detector (SKU: DS160)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.006
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch DS160 Detector (SKU: DS160)
#   Confidence: 0.06741573033707865
#   Lift: 0.7249003262051468
# --Rule: Bosch DS160 Detector (SKU: DS160) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.06741573033707865
#   Lift: 0.7249003262051468
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Bosch F220-B6 Detector Base (SKU: F220-B6)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch F220-B6 Detector Base (SKU: F220-B6)
#   Confidence: 0.08988764044943821
#   Lift: 1.009973488195935
# --Rule: Bosch F220-B6 Detector Base (SKU: F220-B6) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 1.009973488195935
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)
#   Confidence: 0.08988764044943821
#   Lift: 1.009973488195935
# --Rule: Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 1.009973488195935
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)']
# Support: 0.007
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)
#   Confidence: 0.07865168539325844
#   Lift: 0.9710084616451659
# --Rule: Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.07865168539325844
#   Lift: 0.9710084616451659
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)']
# Support: 0.005
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)
#   Confidence: 0.05617977528089888
#   Lift: 0.6242197253433209
# --Rule: Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.05617977528089888
#   Lift: 0.6242197253433209
# ['DSC PG9914 Motion Detector (SKU: PG9914)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.009
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> DSC PG9914 Motion Detector (SKU: PG9914)
#   Confidence: 0.10112359550561797
#   Lift: 1.0533707865168538
# --Rule: DSC PG9914 Motion Detector (SKU: PG9914) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.10112359550561797
#   Lift: 1.0533707865168538
# ['DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.007
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)
#   Confidence: 0.07865168539325844
#   Lift: 0.7562662057044081
# --Rule: DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.07865168539325844
#   Lift: 0.7562662057044081
# ['DSC WS4916 Smoke Detector (SKU: WS4916)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> DSC WS4916 Smoke Detector (SKU: WS4916)
#   Confidence: 0.08988764044943821
#   Lift: 1.009973488195935
# --Rule: DSC WS4916 Smoke Detector (SKU: WS4916) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 1.009973488195935
# ['DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)
#   Confidence: 0.08988764044943821
#   Lift: 1.0331912695337726
# --Rule: DSC WS4933 Carbon Monoxide Detector (SKU: WS4933) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 1.0331912695337726
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'DSC WS4939 Wireless Key (SKU: WS4939)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> DSC WS4939 Wireless Key (SKU: WS4939)
#   Confidence: 0.08988764044943821
#   Lift: 0.8899766381132496
# --Rule: DSC WS4939 Wireless Key (SKU: WS4939) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 0.8899766381132496
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)
#   Confidence: 0.08988764044943821
#   Lift: 0.8560727661851258
# --Rule: Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 0.8560727661851258
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)
#   Confidence: 0.08988764044943821
#   Lift: 1.0575016523463319
# --Rule: Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 1.0575016523463319
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)']
# Support: 0.012
# --Rule:  -> Axis P3225-LVE Network Camera (SKU: 0935-001),GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.012
#   Lift: 1.0
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.012
#   Lift: 1.0
# --Rule: GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.012
#   Lift: 1.0
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R)']
# Support: 0.006
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R)
#   Confidence: 0.06741573033707865
#   Lift: 0.687915615684476
# --Rule: GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.06741573033707865
#   Lift: 0.687915615684476
# ['GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.006
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R)
#   Confidence: 0.06741573033707865
#   Lift: 0.822143052891203
# --Rule: GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.06741573033707865
#   Lift: 0.822143052891203
# ['GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.005
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)
#   Confidence: 0.05617977528089888
#   Lift: 0.5674724775848372
# --Rule: GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.05617977528089888
#   Lift: 0.5674724775848372
# ['GE Interlogix NX-8 Control Panel (SKU: NX-8)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.007
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> GE Interlogix NX-8 Control Panel (SKU: NX-8)
#   Confidence: 0.07865168539325844
#   Lift: 0.904042360842051
# --Rule: GE Interlogix NX-8 Control Panel (SKU: NX-8) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.07865168539325844
#   Lift: 0.904042360842051
# ['Hanwha QND-6010R Network Camera (SKU: QND-6010R)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.005
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Hanwha QND-6010R Network Camera (SKU: QND-6010R)
#   Confidence: 0.05617977528089888
#   Lift: 0.6040836051709557
# --Rule: Hanwha QND-6010R Network Camera (SKU: QND-6010R) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.05617977528089888
#   Lift: 0.6040836051709557
# ['Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)
#   Confidence: 0.08988764044943821
#   Lift: 0.8899766381132496
# --Rule: Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 0.8899766381132496
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)']
# Support: 0.01
# --Rule:  -> Axis P3225-LVE Network Camera (SKU: 0935-001),Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.01
#   Lift: 1.0
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.005
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.05617977528089888
#   Lift: 0.7490636704119851
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.05617977528089888
#   Lift: 0.7490636704119851
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.006
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.06741573033707865
#   Lift: 0.8533636751528942
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.06741573033707865
#   Lift: 0.8533636751528942
# ['Honeywell 5808W3 Smoke Detector (SKU: 5808W3)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.008
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.08988764044943821
#   Lift: 1.0700909577314073
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.08988764044943821
#   Lift: 1.0700909577314073
# ['Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.007
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.07865168539325844
#   Lift: 0.9591668950397371
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.07865168539325844
#   Lift: 0.9591668950397371
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.007
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.07865168539325844
#   Lift: 0.904042360842051
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.07865168539325844
#   Lift: 0.904042360842051
# ['Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.011
# --Rule:  -> Axis P3225-LVE Network Camera (SKU: 0935-001),Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.011
#   Lift: 1.0
# ['Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)', 'Axis P3225-LVE Network Camera (SKU: 0935-001)']
# Support: 0.009
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.10112359550561797
#   Lift: 1.2640449438202246
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.10112359550561797
#   Lift: 1.2640449438202246
# ['Axis P3225-LVE Network Camera (SKU: 0935-001)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.005
# --Rule: Axis P3225-LVE Network Camera (SKU: 0935-001) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.05617977528089888
#   Lift: 0.6688068485821295
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Axis P3225-LVE Network Camera (SKU: 0935-001)
#   Confidence: 0.05617977528089888
#   Lift: 0.6688068485821295
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07777777777777778
#   Lift: 0.8454106280193237
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.8454106280193237
# ['Bosch D7050 Detector (SKU: D7050)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Bosch D7050 Detector (SKU: D7050)
#   Confidence: 0.07777777777777778
#   Lift: 0.7856341189674523
# --Rule: Bosch D7050 Detector (SKU: D7050) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.7856341189674523
# ['Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.005
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)
#   Confidence: 0.05555555555555556
#   Lift: 0.6242197253433209
# --Rule: Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.05555555555555556
#   Lift: 0.6242197253433209
# ['Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.006
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)
#   Confidence: 0.06666666666666667
#   Lift: 0.8230452674897119
# --Rule: Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.06666666666666667
#   Lift: 0.8230452674897119
# ['Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.008
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00)
#   Confidence: 0.08888888888888889
#   Lift: 0.9876543209876544
# --Rule: Bosch NVR-5500-16A00 NVR (SKU: NVR-5500-16A00) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.08888888888888889
#   Lift: 0.9876543209876544
# ['DSC PG9914 Motion Detector (SKU: PG9914)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.011
# --Rule:  -> DSC PG9914 Motion Detector (SKU: PG9914),Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> DSC PG9914 Motion Detector (SKU: PG9914)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: DSC PG9914 Motion Detector (SKU: PG9914) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.011
#   Lift: 1.0
# ['DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.008
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)
#   Confidence: 0.08888888888888889
#   Lift: 0.8547008547008548
# --Rule: DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.08888888888888889
#   Lift: 0.8547008547008548
# ['DSC WS4916 Smoke Detector (SKU: WS4916)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.01
# --Rule:  -> DSC WS4916 Smoke Detector (SKU: WS4916),Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> DSC WS4916 Smoke Detector (SKU: WS4916)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: DSC WS4916 Smoke Detector (SKU: WS4916) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.01
#   Lift: 1.0
# ['DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.005
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> DSC WS4933 Carbon Monoxide Detector (SKU: WS4933)
#   Confidence: 0.05555555555555556
#   Lift: 0.6385696040868456
# --Rule: DSC WS4933 Carbon Monoxide Detector (SKU: WS4933) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.05555555555555556
#   Lift: 0.6385696040868456
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'DSC WS4939 Wireless Key (SKU: WS4939)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> DSC WS4939 Wireless Key (SKU: WS4939)
#   Confidence: 0.07777777777777778
#   Lift: 0.77007700770077
# --Rule: DSC WS4939 Wireless Key (SKU: WS4939) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.77007700770077
# ['Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)
#   Confidence: 0.07777777777777778
#   Lift: 0.7407407407407408
# --Rule: Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.7407407407407408
# ['Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.01
# --Rule:  -> Axis P3367-VE Network Camera (SKU: 0407-001),Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.01
#   Lift: 1.0
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)']
# Support: 0.013
# --Rule:  -> Axis P3367-VE Network Camera (SKU: 0407-001),Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)
#   Confidence: 0.013
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)
#   Confidence: 0.013
#   Lift: 1.0
# --Rule: Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.013
#   Lift: 1.0
# ['GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.01
# --Rule:  -> Axis P3367-VE Network Camera (SKU: 0407-001),GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.01
#   Lift: 1.0
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R)
#   Confidence: 0.07777777777777778
#   Lift: 0.7936507936507936
# --Rule: GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.7936507936507936
# ['GE Interlogix NX-8 Control Panel (SKU: NX-8)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> GE Interlogix NX-8 Control Panel (SKU: NX-8)
#   Confidence: 0.07777777777777778
#   Lift: 0.8939974457215837
# --Rule: GE Interlogix NX-8 Control Panel (SKU: NX-8) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.8939974457215837
# ['Hanwha QND-6010R Network Camera (SKU: QND-6010R)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.006
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Hanwha QND-6010R Network Camera (SKU: QND-6010R)
#   Confidence: 0.06666666666666667
#   Lift: 0.7168458781362007
# --Rule: Hanwha QND-6010R Network Camera (SKU: QND-6010R) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.06666666666666667
#   Lift: 0.7168458781362007
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)']
# Support: 0.006
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)
#   Confidence: 0.06666666666666667
#   Lift: 0.8032128514056225
# --Rule: Hanwha QNV-6010R Network Camera (SKU: QNV-6010R) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.06666666666666667
#   Lift: 0.8032128514056225
# ['Hanwha XRN-2010 NVR (SKU: XRN-2010)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.012
# --Rule:  -> Hanwha XRN-2010 NVR (SKU: XRN-2010),Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.012
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Hanwha XRN-2010 NVR (SKU: XRN-2010)
#   Confidence: 0.012
#   Lift: 1.0
# --Rule: Hanwha XRN-2010 NVR (SKU: XRN-2010) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.012
#   Lift: 1.0
# ['Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)
#   Confidence: 0.07777777777777778
#   Lift: 0.77007700770077
# --Rule: Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.77007700770077
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)']
# Support: 0.008
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)
#   Confidence: 0.08888888888888889
#   Lift: 1.0457516339869282
# --Rule: Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.08888888888888889
#   Lift: 1.0457516339869282
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)
#   Confidence: 0.07777777777777778
#   Lift: 0.8018327605956472
# --Rule: Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.8018327605956472
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.009
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.09999999999999999
#   Lift: 1.2658227848101264
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.09999999999999999
#   Lift: 1.2658227848101264
# ['Honeywell 6160 Keypad (SKU: 6160)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.07777777777777778
#   Lift: 0.8838383838383839
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.8838383838383839
# ['Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.009
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.09999999999999999
#   Lift: 1.219512195121951
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.09999999999999999
#   Lift: 1.219512195121951
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.005
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.05555555555555556
#   Lift: 0.6385696040868456
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.05555555555555556
#   Lift: 0.6385696040868456
# ['Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.006
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.06666666666666667
#   Lift: 0.7662835249042146
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.06666666666666667
#   Lift: 0.7662835249042146
# ['Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.011
# --Rule:  -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US),Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.011
#   Lift: 1.0
# ['Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)', 'Axis P3367-VE Network Camera (SKU: 0407-001)']
# Support: 0.009
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.09999999999999999
#   Lift: 1.1904761904761902
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.09999999999999999
#   Lift: 1.1904761904761902
# ['Axis P3367-VE Network Camera (SKU: 0407-001)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.007
# --Rule: Axis P3367-VE Network Camera (SKU: 0407-001) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.07777777777777778
#   Lift: 0.9370816599732262
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Axis P3367-VE Network Camera (SKU: 0407-001)
#   Confidence: 0.07777777777777778
#   Lift: 0.9370816599732262
# ['Bosch B810 Wireless Receiver (SKU: B810)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Bosch B810 Wireless Receiver (SKU: B810)
#   Confidence: 0.05434782608695653
#   Lift: 0.6246876561719141
# --Rule: Bosch B810 Wireless Receiver (SKU: B810) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.6246876561719141
# ['Bosch D7050 Detector (SKU: D7050)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Bosch D7050 Detector (SKU: D7050)
#   Confidence: 0.07608695652173914
#   Lift: 0.7685551163812033
# --Rule: Bosch D7050 Detector (SKU: D7050) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.7685551163812033
# ['Bosch DS160 Detector (SKU: DS160)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Bosch DS160 Detector (SKU: DS160)
#   Confidence: 0.05434782608695653
#   Lift: 0.5843852267414681
# --Rule: Bosch DS160 Detector (SKU: DS160) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.5843852267414681
# ['Bosch F220-B6 Detector Base (SKU: F220-B6)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Bosch F220-B6 Detector Base (SKU: F220-B6)
#   Confidence: 0.05434782608695653
#   Lift: 0.6106497313141183
# --Rule: Bosch F220-B6 Detector Base (SKU: F220-B6) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.6106497313141183
# ['Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3)
#   Confidence: 0.07608695652173914
#   Lift: 0.8549096238397657
# --Rule: Bosch NDN-50022-A3 IP Camera (SKU: NDN-50022-A3) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.8549096238397657
# ['Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP)
#   Confidence: 0.05434782608695653
#   Lift: 0.6709608158883522
# --Rule: Bosch NDN-832V03-IP IP Camera (SKU: NDN-832V03-IP) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.6709608158883522
# ['DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK)
#   Confidence: 0.05434782608695653
#   Lift: 0.5225752508361204
# --Rule: DSC PowerSeries Neo Alarm Kit (SKU: HS2016NK) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.5225752508361204
# ['DSC WS4916 Smoke Detector (SKU: WS4916)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> DSC WS4916 Smoke Detector (SKU: WS4916)
#   Confidence: 0.05434782608695653
#   Lift: 0.6106497313141183
# --Rule: DSC WS4916 Smoke Detector (SKU: WS4916) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.6106497313141183
# ['DSC WS4939 Wireless Key (SKU: WS4939)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.005
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> DSC WS4939 Wireless Key (SKU: WS4939)
#   Confidence: 0.05434782608695653
#   Lift: 0.5380972879896686
# --Rule: DSC WS4939 Wireless Key (SKU: WS4939) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.05434782608695653
#   Lift: 0.5380972879896686
# ['Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)
#   Confidence: 0.07608695652173914
#   Lift: 0.7246376811594204
# --Rule: Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.7246376811594204
# ['Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.006
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.06521739130434782
#   Lift: 0.6654835847382431
# --Rule: Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.06521739130434782
#   Lift: 0.6654835847382431
# ['Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.006
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z)
#   Confidence: 0.06521739130434782
#   Lift: 0.7672634271099743
# --Rule: Dahua DH-IPC-HFW4431R-Z IP Camera (SKU: DH-IPC-HFW4431R-Z) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.06521739130434782
#   Lift: 0.7672634271099743
# ['GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.07608695652173914
#   Lift: 0.7844016136261767
# --Rule: GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.7844016136261767
# ['GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R)
#   Confidence: 0.07608695652173914
#   Lift: 0.7763975155279503
# --Rule: GE Interlogix 60-746-01-95R Wireless Keypad (SKU: 60-746-01-95R) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.7763975155279503
# ['GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R)
#   Confidence: 0.07608695652173914
#   Lift: 0.9278897136797455
# --Rule: GE Interlogix 60-807-95R Glassbreak Detector (SKU: 60-807-95R) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.9278897136797455
# ['GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.011
# --Rule:  -> GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R),Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: GE Interlogix 60-848-02-95R Smoke Detector (SKU: 60-848-02-95R) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.011
#   Lift: 1.0
# ['GE Interlogix NX-8 Control Panel (SKU: NX-8)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> GE Interlogix NX-8 Control Panel (SKU: NX-8)
#   Confidence: 0.07608695652173914
#   Lift: 0.8745627186406798
# --Rule: GE Interlogix NX-8 Control Panel (SKU: NX-8) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.8745627186406798
# ['Hanwha QND-6010R Network Camera (SKU: QND-6010R)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.008
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Hanwha QND-6010R Network Camera (SKU: QND-6010R)
#   Confidence: 0.08695652173913043
#   Lift: 0.9350163627863487
# --Rule: Hanwha QND-6010R Network Camera (SKU: QND-6010R) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.08695652173913043
#   Lift: 0.9350163627863487
# ['Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Bosch B5512 Control Panel (SKU: B5512)']
# Support: 0.007
# --Rule: Bosch B5512 Control Panel (SKU: B5512) -> Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)
#   Confidence: 0.07608695652173914
#   Lift: 0.9167103195390257
# --Rule: Hanwha QNV-6010R Network Camera (SKU: QNV-6010R) -> Bosch B5512 Control Panel (SKU: B5512)
#   Confidence: 0.07608695652173914
#   Lift: 0.9167103195390257
# ...
#   Lift: 0.74524903738666
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Honeywell 6160 Keypad (SKU: 6160)']
# Support: 0.005
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.06666666666666667
#   Lift: 0.7575757575757576
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.06666666666666667
#   Lift: 0.7575757575757576
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)']
# Support: 0.007
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.09333333333333334
#   Lift: 1.1382113821138211
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.09333333333333334
#   Lift: 1.1382113821138211
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Honeywell HEN08104 NVR (SKU: HEN08104)']
# Support: 0.006
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.08
#   Lift: 0.9195402298850576
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.08
#   Lift: 0.9195402298850576
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)']
# Support: 0.005
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.06666666666666667
#   Lift: 0.7662835249042146
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.06666666666666667
#   Lift: 0.7662835249042146
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)']
# Support: 0.006
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.08
#   Lift: 1.0
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.08
#   Lift: 1.0
# ['Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.006
# --Rule: Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.08
#   Lift: 0.963855421686747
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)
#   Confidence: 0.08
#   Lift: 0.963855421686747
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Honeywell 5808W3 Smoke Detector (SKU: 5808W3)']
# Support: 0.006
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.0759493670886076
#   Lift: 0.9041591320072332
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.0759493670886076
#   Lift: 0.9041591320072332
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)']
# Support: 0.007
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.08860759493670886
#   Lift: 1.080580426057425
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.08860759493670886
#   Lift: 1.080580426057425
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Honeywell HEN08104 NVR (SKU: HEN08104)']
# Support: 0.008
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.10126582278481013
#   Lift: 1.1639749745380474
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.10126582278481013
#   Lift: 1.1639749745380474
# ['Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.006
# --Rule: Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.0759493670886076
#   Lift: 0.9150526155253927
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell 5800PIR-RES Motion Detector (SKU: 5800PIR-RES)
#   Confidence: 0.0759493670886076
#   Lift: 0.9150526155253927
# ['Honeywell 5808W3 Smoke Detector (SKU: 5808W3)', 'Honeywell 6160 Keypad (SKU: 6160)']
# Support: 0.009
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.10714285714285712
#   Lift: 1.2175324675324675
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.10714285714285712
#   Lift: 1.2175324675324675
# ['Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)', 'Honeywell 5808W3 Smoke Detector (SKU: 5808W3)']
# Support: 0.007
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.08333333333333333
#   Lift: 1.0162601626016259
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.08333333333333333
#   Lift: 1.0162601626016259
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Honeywell 5808W3 Smoke Detector (SKU: 5808W3)']
# Support: 0.007
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.08333333333333333
#   Lift: 0.9578544061302682
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.08333333333333333
#   Lift: 0.9578544061302682
# ['Honeywell 5808W3 Smoke Detector (SKU: 5808W3)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)']
# Support: 0.005
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.05952380952380952
#   Lift: 0.6841817186644773
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.05952380952380952
#   Lift: 0.6841817186644773
# ['Honeywell 5808W3 Smoke Detector (SKU: 5808W3)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.011
# --Rule:  -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3),Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.011
#   Lift: 1.0
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.011
#   Lift: 1.0
# ['Honeywell 5808W3 Smoke Detector (SKU: 5808W3)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.007
# --Rule: Honeywell 5808W3 Smoke Detector (SKU: 5808W3) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.08333333333333333
#   Lift: 1.004016064257028
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell 5808W3 Smoke Detector (SKU: 5808W3)
#   Confidence: 0.08333333333333333
#   Lift: 1.004016064257028
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Honeywell 6160 Keypad (SKU: 6160)']
# Support: 0.013
# --Rule:  -> Honeywell HEN08104 NVR (SKU: HEN08104),Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.013
#   Lift: 1.0
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.013
#   Lift: 1.0
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.013
#   Lift: 1.0
# ['Honeywell 6160 Keypad (SKU: 6160)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)']
# Support: 0.005
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.05681818181818182
#   Lift: 0.6530825496342739
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.05681818181818182
#   Lift: 0.6530825496342739
# ['Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)', 'Honeywell 6160 Keypad (SKU: 6160)']
# Support: 0.007
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.07954545454545456
#   Lift: 0.994318181818182
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.07954545454545456
#   Lift: 0.994318181818182
# ['Honeywell 6160 Keypad (SKU: 6160)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.006
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.06818181818181819
#   Lift: 0.8116883116883118
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.06818181818181819
#   Lift: 0.8116883116883118
# ['Honeywell 6160 Keypad (SKU: 6160)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.009
# --Rule: Honeywell 6160 Keypad (SKU: 6160) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.10227272727272727
#   Lift: 1.2322015334063525
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell 6160 Keypad (SKU: 6160)
#   Confidence: 0.10227272727272727
#   Lift: 1.2322015334063525
# ['Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)', 'Honeywell HEN08104 NVR (SKU: HEN08104)']
# Support: 0.006
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.07317073170731707
#   Lift: 0.8410428931875525
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.07317073170731707
#   Lift: 0.8410428931875525
# ['Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.007
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.08536585365853658
#   Lift: 1.0162601626016259
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.08536585365853658
#   Lift: 1.0162601626016259
# ['Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.006
# --Rule: Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.07317073170731707
#   Lift: 0.881575080811049
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell H4D3PRV2 IP Camera (SKU: H4D3PRV2)
#   Confidence: 0.07317073170731707
#   Lift: 0.881575080811049
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)']
# Support: 0.006
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.06896551724137932
#   Lift: 0.792707094728498
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.06896551724137932
#   Lift: 0.792707094728498
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)']
# Support: 0.005
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.0574712643678161
#   Lift: 0.7183908045977012
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.0574712643678161
#   Lift: 0.7183908045977012
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.008
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.09195402298850576
#   Lift: 1.0946907498631637
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.09195402298850576
#   Lift: 1.0946907498631637
# ['Honeywell HEN08104 NVR (SKU: HEN08104)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.01
# --Rule:  -> Honeywell HEN08104 NVR (SKU: HEN08104),Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Honeywell HEN08104 NVR (SKU: HEN08104) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.01
#   Lift: 1.0
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell HEN08104 NVR (SKU: HEN08104)
#   Confidence: 0.01
#   Lift: 1.0
# ['Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)', 'Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)']
# Support: 0.005
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.0574712643678161
#   Lift: 0.7183908045977012
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.0574712643678161
#   Lift: 0.7183908045977012
# ['Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.005
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.0574712643678161
#   Lift: 0.6841817186644773
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.0574712643678161
#   Lift: 0.6841817186644773
# ['Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)', 'Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)']
# Support: 0.008
# --Rule: Honeywell VISTA-20P Control Panel (SKU: VISTA-20P) -> Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS)
#   Confidence: 0.09195402298850576
#   Lift: 1.107879795042238
# --Rule: Pelco Sarix IMP121-1IS IP Camera (SKU: IMP121-1IS) -> Honeywell VISTA-20P Control Panel (SKU: VISTA-20P)
#   Confidence: 0.09195402298850576
#   Lift: 1.107879795042238
# ['Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)', 'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)']
# Support: 0.008
# --Rule: Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US) -> Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)
#   Confidence: 0.1
#   Lift: 1.1904761904761905
# --Rule: Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES) -> Pelco DSSRV2-040-US NVR (SKU: DSSRV2-040-US)
#   Confidence: 0.1
#   Lift: 1.1904761904761905
# ['Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)', 'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)']
# Support: 0.005
# --Rule: Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS) -> Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I),GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.05102040816326531
#   Lift: 5.6689342403628125
# --Rule: GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R) -> Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I),Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.05102040816326531
#   Lift: 5.6689342403628125
# --Rule: Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I) -> Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS),GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.05102040816326531
#   Lift: 5.6689342403628125
# --Rule: GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R),Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS) -> Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I)
#   Confidence: 0.05102040816326531
#   Lift: 5.6689342403628125
# --Rule: Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I),Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS) -> GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)
#   Confidence: 0.05102040816326531
#   Lift: 5.6689342403628125
# --Rule: Hikvision 4MP IP Camera (SKU: DS-2CD2142FWD-I),GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R) -> Dahua DH-IPC-HDBW4431R-ZS IP Camera (SKU: DH-IPC-HDBW4431R-ZS)
#   Confidence: 0.05102040816326531
#   Lift: 5.6689342403628125
# DONE****

# %%
def predict_next_items(transaction, association_results):
    """
    Predicts next probable items for a given transaction based on association rules.

    Args:
        transaction (list): A list of items in the current transaction.
        association_results (list): The list of association rules generated by apriori.
        min_support (float): Minimum support threshold for the rules.
        min_confidence (float): Minimum confidence threshold for the rules.

    Returns:
        list: A list of potential next items.
    """
    min_support = 0.01
    min_confidence = 0.01
    recommendations = []
    for association in association_results:
        antecedent = set(association[0])  # Items on the left-hand side of the rule
        support = association[1]
        if set(transaction).issubset(antecedent)and support >= min_support:
          predicted_items = set()
          # print(association)
          print("antecedent: " + str(antecedent))
          print("support:" + str(support))
          for rule in association[2]:
            LHS = set(rule[0])
            RHS = set(rule[1])
            confidence = rule[2]
            # if LHS.issubset(set(transaction)):
            if LHS == set(transaction):
            # Add the consequent items to the predicted items, excluding items already in the transaction
              predicted_items.update(RHS - set(transaction))
              print("RHS: " + str(RHS))
              print("confidence: " + str(confidence))
              recommendations.append({"items": list(predicted_items), "confidence":confidence})

    # Sort the recommendations by confidence in descending order
    recommendations.sort(key=lambda x: x["confidence"], reverse=True)
    return recommendations

# %%
# my_transaction = test_data.iloc[0].dropna().tolist() # Select the first row and convert to a list of non-null values
my_transaction = ['Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)']
# my_transaction = ['Organic Pink Lemonade Bunny Fruit Snacks', 'Crunch Chocolate Peanut Butter Granola Bar']
print(f"Test data transaction: {my_transaction}")
# Out:
# Test data transaction: ['Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)']

# %%
# Predict the next items
next_items = predict_next_items(my_transaction, association_results)

print(f"Potential next items: {next_items}")
# Out:
# antecedent: {'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.083
# antecedent: {'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.014
# RHS: {'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)'}
# confidence: 0.1686746987951807
# antecedent: {'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.011
# RHS: {'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)'}
# confidence: 0.1325301204819277
# antecedent: {'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)'}
# support:0.011
# RHS: {'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)'}
# confidence: 0.1325301204819277
# antecedent: {'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)'}
# support:0.012
# RHS: {'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)'}
# confidence: 0.14457831325301204
# antecedent: {'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.01
# RHS: {'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)'}
# confidence: 0.12048192771084337
# Potential next items: [{'items': ['Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)'], 'confidence': 0.1686746987951807}, {'items': ['Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)'], 'confidence': 0.14457831325301204}, {'items': ['GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)'], 'confidence': 0.1325301204819277}, {'items': ['Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)'], 'confidence': 0.1325301204819277}, {'items': ['Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)'], 'confidence': 0.12048192771084337}]

# %% [markdown]
# Part II. Build Gradio UI for demo

# %%
# !pip install -qU gradio==4.* pandas pyarrow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 60.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 62.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.2/131.2 kB 11.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 12.0 which is incompatible.
# google-genai 1.49.0 requires websockets<15.1.0,>=13.0.0, but you have websockets 12.0 which is incompatible.
# dataproc-spark-connect 0.8.3 requires websockets>=14.0, but you have websockets 12.0 which is incompatible.
# google-adk 1.17.0 requires websockets<16.0.0,>=15.0.1, but you have websockets 12.0 which is incompatible.

# %%
import ast
import os
import pandas as pd
import gradio as gr

# -------------------------------
# 1) Load inventory (static list)
# -------------------------------
ITEMS_CSV = "item_list.csv"  # columns: item_id, item
item_list_df = pd.read_csv(ITEMS_CSV)
inventory = item_list_df["item"].astype(str).tolist()
print(f"Loaded {len(inventory)} items from '{ITEMS_CSV}'.")

# -------------------------------
# 3) Recommendation function
# -------------------------------
def recommend(selected_items):
    """
    Given a list of selected items (subset of inventory),
    return recommendations ranked by confidence (desc),
    tie-breaking by lift then support if available.
    """
    selected = list(selected_items or [])
    if not selected:
        # As per requirement, return an empty list (no recs without input)
        return pd.DataFrame(columns=["item", "confidence"])

    # Filter rules where rule.antecedents ⊆ selected
    recommendations = predict_next_items(selected_items, association_results)
    if not recommendations:
        return pd.DataFrame(columns=["item", "confidence"])

    df = pd.DataFrame([
    {
        "recommended items": ", ".join(sorted(r["items"])),  # turn set/list into a readable string
        "confidence": r["confidence"]
    }
    for r in recommendations
])
    return df

# -------------------------------
# 4) Gradio UI
# -------------------------------
with gr.Blocks(title="ARM Recommender") as demo:
    gr.Markdown("# Association Rule Recommender")
    gr.Markdown(
        "Select items from your inventory. The recommender returns items implied by your selection via association rules, "
        "ranked by **confidence** (ties by lift/support). If no rule applies, you’ll get an empty list."
    )

    with gr.Row():
        with gr.Column(scale=1):
            gr.Markdown("### Inventory (static)")
            inv_df = gr.Dataframe(
                value=item_list_df,
                wrap=True,
                interactive=False,
                height=300
            )
            gr.Markdown("### Choose items")
            item_selector = gr.CheckboxGroup(
                choices=inventory,
                label="Your items",
                info="Pick one or more items from inventory."
            )
            run_btn = gr.Button("Get Recommendations", variant="primary")

        with gr.Column(scale=1):
            gr.Markdown("### Recommendations")
            recs_out = gr.Dataframe(
                headers=["item", "confidence"],
                interactive=False,
                height=400
            )

    # Wire up
    run_btn.click(fn=recommend, inputs=item_selector, outputs=recs_out)
# Out:
# Loaded 40 items from 'item_list.csv'.

# %%
# Launch (debug=True for debugging mode)
demo.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://84d9459048ed68439a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://84d9459048ed68439a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# antecedent: {'Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)'}
# support:0.075
# antecedent: {'DSC WS4916 Smoke Detector (SKU: WS4916)', 'Honeywell 5800CO Carbon Monoxide Detector (SKU: 5800CO)'}
# support:0.015
# RHS: {'DSC WS4916 Smoke Detector (SKU: WS4916)'}
# confidence: 0.2
# antecedent: {'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.083
# antecedent: {'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.014
# RHS: {'Dahua 8-Channel NVR (SKU: NVR4208-8P-4KS2)'}
# confidence: 0.1686746987951807
# antecedent: {'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.011
# RHS: {'GE Interlogix 60-652-95R Carbon Monoxide Detector (SKU: 60-652-95R)'}
# confidence: 0.1325301204819277
# antecedent: {'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)'}
# support:0.011
# RHS: {'Hikvision DS-2CD2385FWD-I IP Camera (SKU: DS-2CD2385FWD-I)'}
# confidence: 0.1325301204819277
# antecedent: {'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)', 'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)'}
# support:0.012
# RHS: {'Hikvision DS-7608NI-I2/8P NVR (SKU: DS-7608NI-I2/8P)'}
# confidence: 0.14457831325301204
# antecedent: {'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)', 'Hanwha QNV-6010R Network Camera (SKU: QNV-6010R)'}
# support:0.01
# RHS: {'Pelco IMP1110-1ES IP Camera (SKU: IMP1110-1ES)'}
# confidence: 0.12048192771084337
